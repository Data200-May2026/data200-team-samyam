# %%
import pandas as pd

import statsmodels.api as sm

from sklearn.preprocessing import LabelEncoder

df = pd.read_csv("/content/cleaned_data.csv")

for col in df.select_dtypes(include="object"):
    df[col] = LabelEncoder().fit_transform(df[col])

X = df.drop(
    "Projected Openings (2030)",
    axis=1
)

y = df["Projected Openings (2030)"]

X = sm.add_constant(X)

model = sm.OLS(
    y,
    X
).fit()

print(model.summary())
# Out:
#                                 OLS Regression Results
# =====================================================================================
# Dep. Variable:     Projected Openings (2030)   R-squared:                       0.001
# Model:                                   OLS   Adj. R-squared:                  0.000
# Method:                        Least Squares   F-statistic:                     1.270
# Date:                       Thu, 25 Jun 2026   Prob (F-statistic):              0.229
# Time:                               14:58:04   Log-Likelihood:            -2.8139e+05
# No. Observations:                      30000   AIC:                         5.628e+05
# Df Residuals:                          29987   BIC:                         5.629e+05
# Df Model:                                 12
# Covariance Type:                   nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                        5038.1497    104.155     48.372      0.000    4834.001    5242.298
# Job Title                      -0.2218      0.090     -2.477      0.013      -0.397      -0.046
# Industry                       -7.8502      7.242     -1.084      0.278     -22.044       6.344
# Job Status                     33.6707     33.104      1.017      0.309     -31.215      98.556
# AI Impact Level                 0.6133     20.248      0.030      0.976     -39.073      40.300
# Median Salary (USD)         -4.229e-05      0.000     -0.088      0.930      -0.001       0.001
# Required Education             14.9500     11.738      1.274      0.203      -8.057      37.957
# Experience Required (Years)     1.0702      2.731      0.392      0.695      -4.283       6.423
# Job Openings (2024)            -0.0024      0.006     -0.411      0.681      -0.014       0.009
# Remote Work Ratio (%)          -0.2729      0.572     -0.477      0.633      -1.393       0.847
# Automation Risk (%)             0.7607      0.576      1.321      0.186      -0.368       1.889
# Location                       -3.8206      7.219     -0.529      0.597     -17.971      10.330
# Gender Diversity (%)            1.6170      0.958      1.688      0.092      -0.261       3.495
# ==============================================================================
# Omnibus:                    28956.500   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1829.681
# Skew:                          -0.016   Prob(JB):                         0.00
# Kurtosis:                       1.791   Cond. No.                     6.10e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.1e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
